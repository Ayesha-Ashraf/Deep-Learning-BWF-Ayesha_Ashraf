# %% [markdown]
# # Census Project

# %%
import pandas as pd

# %%
import numpy as np

# %%
import glob

# %%
import matplotlib.pyplot as plot

# %%
files = glob.glob('H:\Task1\Deep-Learning-BWF-Ayesha_Ashraf\Project 1\Statesdata\*.csv')

# %%
frame = []
for file in files:
    frame.append(pd.read_csv(file))
us_census = pd.concat(frame)

# %%
us_census
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0               Alabama   4830620  3.7516156462584975%
# 1           1                Alaska    733375   5.909580838323351%
# 2           2               Arizona   6641928  29.565921052631502%
# 3           3              Arkansas   2958208   6.215474452554738%
# 4           4            California  38421464  37.291874687968054%
# 5           5              Colorado   5278906   20.78438003220608%
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
# 5           5               Georgia  10006693   8.418242207460397%
# 0           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_census = us_census.reset_index(drop=True)

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census['GenderPop'] = us_census['GenderPop'].str.replace('M', '')
us_census['GenderPop'] = us_census['GenderPop'].str.replace('F', '')

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census.dropna(inplace = True)

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# ...

# %%
new = us_census["GenderPop"].str.split("_", n = -1, expand = True)

# %%
us_census["Male"]= new[0]
 

us_census["Female"]= new[1]

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# ...

# %%
us_census.columns,us_census.dtypes
# Out:
# (Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#         'Native', 'Asian', 'Pacific', 'Income', 'GenderPop', 'Male', 'Female'],
#        dtype='object'),
#  Unnamed: 0     int64
#  State         object
#  TotalPop       int64
#  Hispanic      object
#  White         object
#  Black         object
#  Native        object
#  Asian         object
#  Pacific       object
#  Income        object
#  GenderPop     object
#  Male          object
#  Female        object
#  dtype: object)

# %%
us_census = us_census.astype({'Male':'int'})

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# Male           int32
# Female        object
# dtype: object

# %%
us_census[["Male", "Female"]] = us_census[["Male", "Female"]].apply(pd.to_numeric)

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income         object
# GenderPop      object
# Male            int32
# Female        float64
# dtype: object

# %%
del us_census["GenderPop"]

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'Male', 'Female'],
#       dtype='object')

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# ...

# %%
f=us_census['TotalPop']-us_census['Male']

# %%
f
# Out:
# 0      2489527
# 1       349215
# 2      3342840
# 3      1506295
# 4     19334329
# 7      1841615
# 9       340810
# 10    10045763
# 11     5123362
# 12     5123362
# 13      696428
# 14      806083
# 15     6556862
# 16     3333382
# 17     1558931
# 18     1558931
# 20     2233145
# 21     2364097
# 22      679019
# 23     3057895
# 24     3057895
# 25     3455936
# 26     5038598
# 27     2727005
# 28     1536358
# 29     3081445
# 30     3081445
# 31      504536
# 32      939759
# 33     1390901
# 34      670717
# 35     4561386
# 36     4561386
# 37     1051703
# 38    10131373
# 39     5049925
# 41     5913084
# 42     5913084
# 43     1942789
# 44     1990780
# 45     6534215
# 46     1869213
# 47      543273
# 48      543273
# 49     2455167
# 50      419713
# 51     3331859
# 52    13367298
# 53     1444150
# 54     1444150
# 55      318031
# 56     4195682
# 57     3497739
# 58      937789
# 59     2890732
# dtype: int64

# %%
us_census['Female'].fillna(value=f)
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334329.0
# 7      1841615.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 23     3057895.0
# 24     3057895.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 31      504536.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# 52    13367298.0
# 53     1444150.0
# 54     1444150.0
# 55      318031.0
# 56     4195682.0
# ...

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# ...

# %%
us_census['Female']=us_census['TotalPop']-us_census['Male']

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# ...

# %%
us_census['Female']
# Out:
# 0      2489527
# 1       349215
# 2      3342840
# 3      1506295
# 4     19334329
# 7      1841615
# 9       340810
# 10    10045763
# 11     5123362
# 12     5123362
# 13      696428
# 14      806083
# 15     6556862
# 16     3333382
# 17     1558931
# 18     1558931
# 20     2233145
# 21     2364097
# 22      679019
# 23     3057895
# 24     3057895
# 25     3455936
# 26     5038598
# 27     2727005
# 28     1536358
# 29     3081445
# 30     3081445
# 31      504536
# 32      939759
# 33     1390901
# 34      670717
# 35     4561386
# 36     4561386
# 37     1051703
# 38    10131373
# 39     5049925
# 41     5913084
# 42     5913084
# 43     1942789
# 44     1990780
# 45     6534215
# 46     1869213
# 47      543273
# 48      543273
# 49     2455167
# 50      419713
# 51     3331859
# 52    13367298
# 53     1444150
# 54     1444150
# 55      318031
# 56     4195682
# 57     3497739
# 58      937789
# 59     2890732
# Name: Female, dtype: int64

# %%
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_census.duplicated(us_census.columns)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_census['State'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 7     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# Name: State, dtype: bool

# %%
Us_census=us_census.drop_duplicates(subset=['State','TotalPop','Hispanic','White','Black','Native','Asian','Pacific','Income','Female','Male'])

# %%
Us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# 16           4               Indiana   6568645   6.536744186046501%
# ...

# %%
Us_census.reset_index(drop=True)
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            1           Connecticut   3593222  15.604830917874388%
# 6            3  District of Columbia    647484   9.165921787709499%
# 7            4               Florida  19645772    21.3385426653884%
# 8            5               Georgia  10006693   8.418242207460397%
# 9            1                Hawaii   1406299   9.186708860759486%
# 10           2                 Idaho   1616547  11.505369127516781%
# 11           3              Illinois  12873761  15.601733547351516%
# 12           4               Indiana   6568645   6.536744186046501%
# ...

# %%
Us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'Male', 'Female'],
#       dtype='object')

# %%
Us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 7            1           Connecticut   3593222  15.604830917874388%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# 15           3              Illinois  12873761  15.601733547351516%
# 16           4               Indiana   6568645   6.536744186046501%
# ...

# %%
us_census=Us_census.reset_index(drop=True)

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            1           Connecticut   3593222  15.604830917874388%
# 6            3  District of Columbia    647484   9.165921787709499%
# 7            4               Florida  19645772    21.3385426653884%
# 8            5               Georgia  10006693   8.418242207460397%
# 9            1                Hawaii   1406299   9.186708860759486%
# 10           2                 Idaho   1616547  11.505369127516781%
# 11           3              Illinois  12873761  15.601733547351516%
# 12           4               Indiana   6568645   6.536744186046501%
# ...

# %%
us_census['Hispanic'] = us_census['Hispanic'].str.replace('%', '')
us_census['White'] = us_census['White'].str.replace('%', '')
us_census['Black'] = us_census['Black'].str.replace('%', '')
us_census['Asian'] = us_census['Asian'].str.replace('%', '')
us_census['Pacific'] = us_census['Pacific'].str.replace('%', '')
us_census['Native'] = us_census['Native'].str.replace('%', '')

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop            Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975
# 1            1                Alaska    733375   5.909580838323351
# 2            2               Arizona   6641928  29.565921052631502
# 3            3              Arkansas   2958208   6.215474452554738
# 4            4            California  38421464  37.291874687968054
# 5            1           Connecticut   3593222  15.604830917874388
# 6            3  District of Columbia    647484   9.165921787709499
# 7            4               Florida  19645772    21.3385426653884
# 8            5               Georgia  10006693   8.418242207460397
# 9            1                Hawaii   1406299   9.186708860759486
# 10           2                 Idaho   1616547  11.505369127516781
# 11           3              Illinois  12873761  15.601733547351516
# 12           4               Indiana   6568645   6.536744186046501
# ...

# %%
us_census[["Pacific", "Native","Asian","Hispanic","White","Black","TotalPop","Income"]] = us_census[["Pacific", "Native","Asian","Hispanic","White","Black","TotalPop","Income"]].apply(pd.to_numeric)

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income        float64
# Male            int32
# Female          int64
# dtype: object

# %%
Races=us_census[["Pacific", "Native","Asian","Hispanic","White","Black","TotalPop"]]

# %%
Races
# Out:
#      Pacific     Native      Asian   Hispanic      White      Black  TotalPop
# 0   0.034354   0.453231   1.050255   3.751616  61.878656  31.252976   4830620
# 1   1.058683  16.391018   5.450299   5.909581  60.910180   2.848503    733375
# 2   0.167632   4.355066   2.876579  29.565921  57.120000   3.850987   6641928
# 3   0.146861   0.522920   1.142336   6.215474  71.137810  18.968759   2958208
# 4   0.351410   0.405292  13.052234  37.291875  40.215789   5.677396  38421464
# 5   0.018599   0.126208   4.021981  15.604831  67.677053  10.348068   3593222
# 6   0.029609   0.200559   3.383240   9.165922  33.103911  51.776536    647484
# 7   0.051510   0.210451   2.283174  21.338543  59.083749  15.165676  19645772
# 8   0.046602   0.187583   3.097649   8.418242  54.286306  32.088298  10006693
# 9   8.758861   0.144937  36.592089   9.186709  25.032278   2.052848   1406299
# 10  0.127181   1.468121   1.135906  11.505369  83.136242   0.566779   1616547
# ...

# %%
us_census.plot.bar(x="State", y="Pacific" , title="Number of Races in differnt States",color=[
         'Blue', 'Red'])

plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="White" , title="Number of Races in differnt States",color=[
         'purple', 'Red'])

plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="Asian" , title="Number of Races in differnt States",color=[
         'Black', 'Yellow'])

plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="Hispanic" , title="Number of Races in differnt States",color=[
         'orange', 'Red'])
plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="Native" , title="Number of Races in differnt States",color=[
         'green', 'Red'])
plot.show(block=True)

# %%
us_census.plot(x='Income',y='Female',kind = 'hist', title = 'Proportion b/w Income and Female in the different States',color=[
         'Black', 'Pink'])
plot.show()

# %%
us_census.plot(x='State',y='Female',kind = 'hist', title = 'Proportion of Female in the different States',color=[
         'Pink'])
plot.show()

# %%
us_census['Income'] = us_census['Income'].str.replace('$', '',regex=True)

# %%
us_census
# Out:
#     Unnamed: 0                 State  TotalPop   Hispanic      White  \
# 0            0               Alabama   4830620   3.751616  61.878656
# 1            1                Alaska    733375   5.909581  60.910180
# 2            2               Arizona   6641928  29.565921  57.120000
# 3            3              Arkansas   2958208   6.215474  71.137810
# 4            4            California  38421464  37.291875  40.215789
# 5            1           Connecticut   3593222  15.604831  67.677053
# 6            3  District of Columbia    647484   9.165922  33.103911
# 7            4               Florida  19645772  21.338543  59.083749
# 8            5               Georgia  10006693   8.418242  54.286306
# 9            1                Hawaii   1406299   9.186709  25.032278
# 10           2                 Idaho   1616547  11.505369  83.136242
# 11           3              Illinois  12873761  15.601734  60.859807
# 12           4               Indiana   6568645   6.536744  78.431894
# ...

# %%
us_census.plot(x='State',y='Income',kind = 'hist', title = 'Proportion of Income in the different States',color=[
         'Yellow', 'Red'])
plot.show()

# %%
us_census.plot.bar(x="State", y="Income" , title="Proporttion of Income differnt States",color=[
         'Blue', 'Purple'])
plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="Female" , title="Proporttion of Female differnt States",color=[
         'Orange', 'Pink'])
plot.show(block=True)

# %%
us_census.plot.bar(x="Female", y="Income" , title="Proporttion of Female Income  differnt States",color=[
         'Black', 'Red'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Hispanic" , title="Number of Races in differnt States",color=[
         'orange', 'Red'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Pacific" , title="Number of Races in differnt States",color=[
         'Red'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="White" , title="Number of Races in differnt States",color=[
         'Purple'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Black" , title="Number of Races in differnt States",color=[
         'Green'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Asian" , title="Number of Races in differnt States",color=[
         'Orange'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Native" , title="Number of Races in differnt States",color=[
         'Yellow', ])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Income" , title="Prportion of Income in differnt States",color=[
         'orange', 'Red'])
plot.show(block=True)

# %%
us_census.plot.hist(x="State", y="Female" , title="Prportion of Female in differnt States",color=[
          'Red'])
plot.show(block=True)

# %%
us_census.plot.hist(x="Female", y="Income" , title="Prportion of Income of female in states",color=[
         'Blue'])
plot.show(block=True)

# %%
us_census.plot.bar(x="State", y="Black" , title="Number of Races in differnt States",color=[
         'Skyblue', 'Pink'])

plot.show(block=True)
